# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('house_rate.csv')
data = data.dropna()
data.head()
# Out:
#    House Size(sqft)  Price($)
# 0              1200    500000
# 1              1500    600000
# 2              1700    700000
# 3              1600    550000
# 4              1300    580000

# %%
X = data['House Size(sqft)'].to_list()
X = np.reshape(X, newshape = (-1,1))
Y = data['Price($)'].to_list()

# %%
plt.scatter(X, Y, color = 'red')
plt.xlabel('Size (sq ft)')
plt.ylabel('Price ($)')
plt.title('Size vs Price of Houses')
plt.show()

# %%
model = LinearRegression()
model.fit(X, Y)
print("Slopes(m) =",model.coef_)
print("Constant(c) =",model.intercept_)
print("Linear Equation: y = mx + c")
print(f"y = {model.coef_}x + {model.intercept_}")
# Out:
# Slopes(m) = [302.24281742]
# Constant(c) = 178771.08433734957
# Linear Equation: y = mx + c
# y = [302.24281742]x + 178771.08433734957

# %%
x_new = [[600]]
y_pred = model.predict(x_new)
print("Independent Variables:",x_new)
print("Dependent Variable:",y_pred)
# Out:
# Independent Variables: [[600]]
# Dependent Variable: [360116.77479147]

# %%
plt.scatter(X, Y, color = 'red', label = 'Actual')
plt.plot(X, model.predict(X), color = 'green', label = 'Predicted')
plt.legend()
plt.title("Linear Regression")
plt.show()

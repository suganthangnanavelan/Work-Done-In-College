# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
import numpy as np

# Define your text data
text = "This is a sample text for text generation using LSTM."

# Preprocess the text data
chars = sorted(list(set(text)))
char_to_int = {char: i for i, char in enumerate(chars)}
int_to_char = {i: char for i, char in enumerate(chars)}
num_chars = len(chars)
seq_length = 10

data_X = []
data_y = []
for i in range(0, len(text) - seq_length):
    seq_in = text[i:i+seq_length]
    seq_out = text[i+seq_length]
    data_X.append([char_to_int[char] for char in seq_in])
    data_y.append(char_to_int[seq_out])

X = np.reshape(data_X, (len(data_X), seq_length, 1))
X = X / float(num_chars)
y = np.eye(num_chars)[data_y]

# Define and train the LSTM model
model = Sequential()
model.add(LSTM(128, input_shape=(X.shape[1], X.shape[2])))
model.add(Dense(num_chars, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')

model.fit(X, y, epochs=100, batch_size=16)

# Generate text using the trained model
start_seq = "This is a "
generated_text = start_seq

for _ in range(50):
    x = np.reshape([char_to_int[char] for char in start_seq], (1, len(start_seq), 1))
    x = x / float(num_chars)
    prediction = model.predict(x, verbose=0)
    index = np.argmax(prediction)
    result = int_to_char[index]
    generated_text += result
    start_seq = start_seq[1:] + result
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 3.0941
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - loss: 3.0640
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.0418
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.0099
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0112
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9696
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9300
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8613
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8466
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8628
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8738
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8585
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8464
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8646
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8752
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8535
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7983
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8656
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8281
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7468
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7849
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8374
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8164
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7531
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7931
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7887
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7903
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7960
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7591
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8337
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7248
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8150
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8044
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8259
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7688
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7815
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7502
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7021
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7698
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7319
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7654
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6872
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7100
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6578
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.6758
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6595
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 2.7162
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.6271
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5642
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6096
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5808
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5255
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.6616
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5042
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5800
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5030
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 2.4356
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5286
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5167
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.4016
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.4224
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3820
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4060
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3358
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.3763
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.2612
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3534
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.1895
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 2.3127
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1974
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2685
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2792
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2679
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1196
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2362
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1291
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2470
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2019
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1425
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1447
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1005
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0450
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0722
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0825
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0148
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0104
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9667
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0018
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9120
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 2.0104
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8398
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9826
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9162
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 1.9284
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0108
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9277
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8149
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - loss: 1.9917
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8685
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9353

# %%
print("Generated Text:",generated_text)
# Out:
# Generated Text: This is a emmplll  sTa.pppl oo etat  oemppp o rTaaappll o ex

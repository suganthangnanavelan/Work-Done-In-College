# %%
import tensorflow as tf
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data.csv')
df.head
# Out:
# <bound method NDFrame.head of                                                   english  \
# 0                                                     Go.
# 1                                                     Go.
# 2                                                     Go.
# 3                                                     Go.
# 4                                                     Hi.
# ...                                                   ...
# 118959  There are four main causes of alcohol-related ...
# 118960  There are mothers and fathers who will lie awa...
# 118961  A carbon footprint is the amount of carbon dio...
# 118962  Since there are usually multiple websites on a...
# 118963  If you want to sound like a native speaker, yo...
#
#                                                   spanish
# 0                                                     Ve.
# 1                                                   Vete.
# 2                                                   Vaya.
# 3                                                 Váyase.
# 4                                                   Hola.
# ...                                                   ...
# 118959  Hay cuatro causas principales de muertes relac...
# 118960  Hay madres y padres que se quedan despiertos d...
# 118961  Una huella de carbono es la cantidad de contam...
# 118962  Como suele haber varias páginas web sobre cual...
# 118963  Si quieres sonar como un hablante nativo, debe...
#
# [118964 rows x 2 columns]>

# %%
df.columns
# Out:
# Index(['english', 'spanish'], dtype='object')

# %%
source_vocab = set(' '.join(df['english'][25:125]))
target_vocab = set(' '.join(df['spanish'][25:125]))
source_vocab_size = len(source_vocab)
target_vocab_size = len(target_vocab)

# %%
print(source_vocab)
print(target_vocab)
# Out:
# {'D', 'l', '!', 'i', 'T', 'R', ' ', '1', 'S', "'", 'N', 'O', 'x', 'm', 'f', 'L', 'W', 'H', 'w', 'C', '?', 'o', 't', 'h', 'k', 'c', 'r', 'e', 'q', 'I', 'G', 'g', '9', 'b', 'p', 'a', 's', 'n', 'd', 'B', 'y', 'u', '.', 'A'}
# {'í', 'Ó', 'P', 'D', 'l', 'i', '!', 'á', 'T', 'R', 'ú', 'S', 'M', 'N', 'O', 'm', 'ó', 'f', 'L', 'é', 'H', 'C', '?', 'o', ',', 't', 'h', 'E', 'Á', 'c', 'r', 'e', 'j', 'q', 'g', 'V', 'I', 'G', 'b', '¡', 'p', '.', 'a', 'z', 's', 'Y', 'É', 'v', '¿', 'n', 'd', 'B', 'U', 'y', 'u', ' ', 'A'}

# %%
source_char_to_int = {char: idx for idx, char in enumerate(source_vocab)}
target_char_to_int = {char: idx for idx, char in enumerate(target_vocab)}
source_int_to_char = {idx: char for char, idx in source_char_to_int.items()}
target_int_to_char = {idx: char for char, idx in target_char_to_int.items()}

# %%
# Convert text sequences to integer sequences
source_sequences = [[source_char_to_int[char] for char in text] for text in df['english'][25:125]]
target_sequences = [[target_char_to_int[char] for char in text] for text in df['spanish'][25:125]]

# %%
# Pad sequences to the same length
max_sequence_length = max(len(seq) for seq in source_sequences)
source_sequences = tf.keras.preprocessing.sequence.pad_sequences(source_sequences, maxlen=max_sequence_length, padding='post')
target_sequences = tf.keras.preprocessing.sequence.pad_sequences(target_sequences, maxlen=max_sequence_length, padding='post')

# %%
# Build the model
input_shape = (max_sequence_length, source_vocab_size)
output_shape = (max_sequence_length, target_vocab_size)

model = tf.keras.models.Sequential([
    # Embedding layer with a larger dimension for richer word representations
    tf.keras.layers.Embedding(source_vocab_size, 512, input_length=max_sequence_length),

    # First Bidirectional RNN layer with dropout and L2 regularization
    tf.keras.layers.Bidirectional(tf.keras.layers.SimpleRNN(512, return_sequences=True, 
                                kernel_regularizer=tf.keras.regularizers.l2(0.001))),
    tf.keras.layers.Dropout(0.4),

    # Second RNN layer with higher units and dropout
    tf.keras.layers.SimpleRNN(512, return_sequences=True),
    tf.keras.layers.Dropout(0.4),

    # Third RNN layer for more complex patterns
    tf.keras.layers.SimpleRNN(256, return_sequences=True),
    tf.keras.layers.Dropout(0.3),

    # Dense layer for more feature learning
    tf.keras.layers.Dense(512, activation='relu'),

    # Output layer to map to the target vocabulary
    tf.keras.layers.Dense(target_vocab_size, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
# One-hot encode the target sequences
target_sequences_one_hot = np.array([tf.keras.utils.to_categorical(seq, num_classes=target_vocab_size) for seq in target_sequences])

# %%
# Train the model
model.fit(source_sequences, target_sequences_one_hot,batch_size = 64, epochs=250)
# Out:
# Epoch 1/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.0469 - loss: 5.0094
# Epoch 2/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.1789 - loss: 4.3173
# Epoch 3/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.1964 - loss: 3.9905
# Epoch 4/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2272 - loss: 3.8061
# Epoch 5/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2491 - loss: 3.6146
# Epoch 6/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.2903 - loss: 3.4823
# Epoch 7/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.3142 - loss: 3.3077
# Epoch 8/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3746 - loss: 3.1610
# Epoch 9/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.4041 - loss: 3.0410
# Epoch 10/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.4159 - loss: 2.9495
# Epoch 11/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4367 - loss: 2.8008
# Epoch 12/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.4671 - loss: 2.7200
# Epoch 13/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.4879 - loss: 2.5894
# Epoch 14/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.4859 - loss: 2.5800
# Epoch 15/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5225 - loss: 2.4418
# Epoch 16/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5418 - loss: 2.3120
# Epoch 17/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5356 - loss: 2.2551
# Epoch 18/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5543 - loss: 2.1336
# Epoch 19/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5896 - loss: 2.0694
# Epoch 20/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5913 - loss: 2.0148
# Epoch 21/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6096 - loss: 1.9789
# Epoch 22/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5712 - loss: 1.9375
# Epoch 23/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6285 - loss: 1.8438
# Epoch 24/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6296 - loss: 1.8180
# Epoch 25/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6573 - loss: 1.7583
# Epoch 26/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6284 - loss: 1.7271
# Epoch 27/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6527 - loss: 1.7116
# Epoch 28/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6587 - loss: 1.6766
# Epoch 29/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6805 - loss: 1.5802
# Epoch 30/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6450 - loss: 1.6031
# Epoch 31/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6720 - loss: 1.5405
# Epoch 32/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6978 - loss: 1.4849
# Epoch 33/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6767 - loss: 1.4990
# Epoch 34/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6608 - loss: 1.5080
# Epoch 35/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6814 - loss: 1.4810
# Epoch 36/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6651 - loss: 1.4499
# Epoch 37/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6803 - loss: 1.4430
# Epoch 38/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7019 - loss: 1.3365
# Epoch 39/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7140 - loss: 1.3342
# Epoch 40/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7069 - loss: 1.3088
# Epoch 41/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6782 - loss: 1.3735
# Epoch 42/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6910 - loss: 1.3540
# Epoch 43/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6762 - loss: 1.3503
# Epoch 44/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7110 - loss: 1.2652
# Epoch 45/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6811 - loss: 1.3062
# Epoch 46/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6901 - loss: 1.2799
# Epoch 47/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7170 - loss: 1.2039
# Epoch 48/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7110 - loss: 1.1952
# Epoch 49/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7179 - loss: 1.2088
# Epoch 50/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7077 - loss: 1.2141
# Epoch 51/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6844 - loss: 1.2419
# Epoch 52/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.
250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7248 - loss: 0.6954
# Epoch 193/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7172 - loss: 0.6974
# Epoch 194/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7132 - loss: 0.7002
# Epoch 195/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7258 - loss: 0.6998
# Epoch 196/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7066 - loss: 0.6914
# Epoch 197/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7196 - loss: 0.6842
# Epoch 198/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7163 - loss: 0.7118
# Epoch 199/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7163 - loss: 0.6843
# Epoch 200/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7078 - loss: 0.7040
# Epoch 201/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7055 - loss: 0.7191
# Epoch 202/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7086 - loss: 0.6866
# Epoch 203/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6877 - loss: 0.7436
# Epoch 204/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6861 - loss: 0.7375
# Epoch 205/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7195 - loss: 0.6821
# Epoch 206/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7107 - loss: 0.6883
# Epoch 207/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7318 - loss: 0.6618
# Epoch 208/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7063 - loss: 0.7098
# Epoch 209/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7051 - loss: 0.6967
# Epoch 210/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7203 - loss: 0.6881
# Epoch 211/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6976 - loss: 0.7021
# Epoch 212/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7116 - loss: 0.7052
# Epoch 213/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7133 - loss: 0.6944
# Epoch 214/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7120 - loss: 0.6692
# Epoch 215/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7176 - loss: 0.7183
# Epoch 216/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7284 - loss: 0.6668
# Epoch 217/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7320 - loss: 0.6465
# Epoch 218/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7158 - loss: 0.6696
# Epoch 219/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7253 - loss: 0.6764
# Epoch 220/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7182 - loss: 0.6768
# Epoch 221/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7019 - loss: 0.6739
# Epoch 222/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7258 - loss: 0.6412
# Epoch 223/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7027 - loss: 0.6942
# Epoch 224/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7150 - loss: 0.6828
# Epoch 225/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7258 - loss: 0.6568
# Epoch 226/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7202 - loss: 0.6623
# Epoch 227/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7045 - loss: 0.7053
# Epoch 228/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7035 - loss: 0.6864
# Epoch 229/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7190 - loss: 0.6696
# Epoch 230/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7024 - loss: 0.6931
# Epoch 231/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7167 - loss: 0.6678
# Epoch 232/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7211 - loss: 0.6819
# Epoch 233/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7160 - loss: 0.6643
# Epoch 234/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6970 - loss: 0.6933
# Epoch 235/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6957 - loss: 0.6944
# Epoch 236/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6934 - loss: 0.6889
# Epoch 237/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7144 - loss: 0.6685
# Epoch 238/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7016 - loss: 0.6848
# Epoch 239/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7084 - loss: 0.6814
# Epoch 240/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7161 - loss: 0.6736
# Epoch 241/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7126 - loss: 0.6634
# Epoch 242/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7096 - loss: 0.6962
# Epoch 243/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7073 - loss: 0.6702
# Epoch 244/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7066 - loss: 0.6671
# Epoch 245/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7233 - loss: 0.6335
# Epoch 246/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6955 - loss: 0.6807
# Epoch 247/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7189 - loss: 0.6488
# Epoch 248/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7204 - loss: 0.6565
# Epoch 249/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6995 - loss: 0.6934
# Epoch 250/250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7142 - loss: 0.6912

# %%
# Translate a new input sequence
x = input("Enter String : ")
input_sequence = x
input_sequence = [source_char_to_int[char] for char in input_sequence]
input_sequence = tf.keras.preprocessing.sequence.pad_sequences([input_sequence], maxlen=max_sequence_length, padding='post')
output_sequence = model.predict(input_sequence)[0]
# Decode the output sequence
output_sequence = [target_int_to_char[np.argmax(char)] for char in output_sequence]
print("Input Sequence:",x)
print("Translated Sequence:", ''.join(output_sequence))
# Out:
# Enter String :  Thanks!.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Input Sequence: Thanks!.
# Translated Sequence: Gracias!

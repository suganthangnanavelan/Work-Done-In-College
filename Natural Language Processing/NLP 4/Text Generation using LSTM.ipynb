# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
import numpy as np

# Define your text data
text = "This is a sample text for text generation using LSTM."

# Preprocess the text data
chars = sorted(list(set(text)))
char_to_int = {char: i for i, char in enumerate(chars)}
int_to_char = {i: char for i, char in enumerate(chars)}
num_chars = len(chars)
seq_length = 10

data_X = []
data_y = []
for i in range(0, len(text) - seq_length):
    seq_in = text[i:i+seq_length]
    seq_out = text[i+seq_length]
    data_X.append([char_to_int[char] for char in seq_in])
    data_y.append(char_to_int[seq_out])

X = np.reshape(data_X, (len(data_X), seq_length, 1))
X = X / float(num_chars)
y = np.eye(num_chars)[data_y]

# Define and train the LSTM model
model = Sequential()
model.add(LSTM(128, input_shape=(X.shape[1], X.shape[2])))
model.add(Dense(num_chars, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')

model.fit(X, y, epochs=100, batch_size=16)

# Generate text using the trained model
start_seq = "This is a "
generated_text = start_seq

for _ in range(50):
    x = np.reshape([char_to_int[char] for char in start_seq], (1, len(start_seq), 1))
    x = x / float(num_chars)
    prediction = model.predict(x, verbose=0)
    index = np.argmax(prediction)
    result = int_to_char[index]
    generated_text += result
    start_seq = start_seq[1:] + result

print(generated_text)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 2s 13ms/step - loss: 3.0814
# Epoch 2/100
# 3/3 [==============================] - 0s 12ms/step - loss: 3.0538
# Epoch 3/100
# 3/3 [==============================] - 0s 13ms/step - loss: 3.0327
# Epoch 4/100
# 3/3 [==============================] - 0s 12ms/step - loss: 3.0081
# Epoch 5/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.9773
# Epoch 6/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.9416
# Epoch 7/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.8934
# Epoch 8/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.8761
# Epoch 9/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.8701
# Epoch 10/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.8650
# Epoch 11/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.8487
# Epoch 12/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.8399
# Epoch 13/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.8411
# Epoch 14/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.8369
# Epoch 15/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.8319
# Epoch 16/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.8314
# Epoch 17/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.8299
# Epoch 18/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.8272
# Epoch 19/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.8259
# Epoch 20/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.8218
# Epoch 21/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.8214
# Epoch 22/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.8201
# Epoch 23/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.8171
# Epoch 24/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.8212
# Epoch 25/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.8146
# Epoch 26/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.8116
# Epoch 27/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.8108
# Epoch 28/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.8091
# Epoch 29/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.8076
# Epoch 30/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.8080
# Epoch 31/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.8015
# Epoch 32/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.7974
# Epoch 33/100
# 3/3 [==============================] - 0s 11ms/step - loss: 2.7995
# Epoch 34/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.7947
# Epoch 35/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.7938
# Epoch 36/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.7870
# Epoch 37/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.7836
# Epoch 38/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.7833
# Epoch 39/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7749
# Epoch 40/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.7677
# Epoch 41/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.7596
# Epoch 42/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.7599
# Epoch 43/100
# 3/3 [==============================] - 0s 12ms/step - loss: 2.7422
# Epoch 44/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.7323
# Epoch 45/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.7200
# Epoch 46/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2.7005
# Epoch 47/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.6986
# Epoch 48/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.6953
# Epoch 49/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2.6842
# Epoch 50/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.6726
# Epoch 51/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.6660
# Epoch 52/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.6363
# Epoch 53/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.6074
# Epoch 54/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.6035
# Epoch 55/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.5875
# Epoch 56/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.6009
# Epoch 57/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.5479
# Epoch 58/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.5328
# Epoch 59/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2.5000
# Epoch 60/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.4774
# Epoch 61/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.5492
# Epoch 62/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.4640
# Epoch 63/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.4343
# Epoch 64/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.4382
# Epoch 65/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.4170
# Epoch 66/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.3897
# Epoch 67/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.3674
# Epoch 68/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.3501
# Epoch 69/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.3383
# Epoch 70/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.3089
# Epoch 71/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.3383
# Epoch 72/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.2974
# Epoch 73/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.2858
# Epoch 74/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2.3051
# Epoch 75/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.2262
# Epoch 76/100
# 3/3 [==============================] - 0s 22ms/step - loss: 2.2349
# Epoch 77/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.2466
# Epoch 78/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.1873
# Epoch 79/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.1898
# Epoch 80/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.1487
# Epoch 81/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.1016
# Epoch 82/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.1179
# Epoch 83/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.0715
# Epoch 84/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.0920
# Epoch 85/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.0995
# Epoch 86/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.0618
# Epoch 87/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.0372
# Epoch 88/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.0018
# Epoch 89/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.9799
# Epoch 90/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.9973
# Epoch 91/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.9362
# Epoch 92/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.9132
# Epoch 93/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.8939
# Epoch 94/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.9069
# Epoch 95/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.9107
# Epoch 96/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1.9625
# Epoch 97/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.8766
# Epoch 98/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8318
# Epoch 99/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1.8404
# Epoch 100/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1.8333
# This is a ea.pppp  grTa.ppp  oeetppl geSTM.pppll  eTM..ppp
